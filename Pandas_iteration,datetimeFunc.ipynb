# %% [markdown]
# <a href="https://colab.research.google.com/github/Ravichandu2003/Pandas/blob/main/Pandas_iteration%2CdatetimeFunc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv("airtravel.csv")
data.head()
# Out:
#   Month   "1958"   "1959"   "1960"
# 0   JAN      340      360      417
# 1   FEB      318      342      391
# 2   MAR      362      406      419
# 3   APR      348      396      461
# 4   MAY      363      420      472

# %% [markdown]
# ##3 Ways for Iteration in Pandas
# 1. iteritems(): Helps to iterate over each element of the set, column-wise.
# 2. iterrows(): Each element of the set, row-wise.
# 3. itertuple(): Each row and form a tuple out of them.

# %%
#iteritems()
for key,values in data.iteritems():
  print(key, values)
# Out:
# Month 0     JAN
# 1     FEB
# 2     MAR
# 3     APR
# 4     MAY
# 5     JUN
# 6     JUL
# 7     AUG
# 8     SEP
# 9     OCT
# 10    NOV
# 11    DEC
# Name: Month, dtype: object
#  "1958" 0     340
# 1     318
# 2     362
# 3     348
# 4     363
# 5     435
# 6     491
# 7     505
# 8     404
# 9     359
# 10    310
# 11    337
# Name:  "1958", dtype: int64
#  "1959" 0     360
# 1     342
# 2     406
# 3     396
# 4     420
# 5     472
# 6     548
# 7     559
# 8     463
# 9     407
# 10    362
# 11    405
# Name:  "1959", dtype: int64
#  "1960" 0     417
# 1     391
# 2     419
# 3     461
# 4     472
# 5     535
# 6     622
# 7     606
# 8     508
# 9     461
# 10    390
# 11    432
# Name:  "1960", dtype: int64
# <ipython-input-26-2437016d0061>:2: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for key,values in data.iteritems():

# %%
#iterrows()
for row_index,row in data.iterrows():
  print(row_index,row)
# Out:
# 0 Month      JAN
#  "1958"    340
#  "1959"    360
#  "1960"    417
# Name: 0, dtype: object
# 1 Month      FEB
#  "1958"    318
#  "1959"    342
#  "1960"    391
# Name: 1, dtype: object
# 2 Month      MAR
#  "1958"    362
#  "1959"    406
#  "1960"    419
# Name: 2, dtype: object
# 3 Month      APR
#  "1958"    348
#  "1959"    396
#  "1960"    461
# Name: 3, dtype: object
# 4 Month      MAY
#  "1958"    363
#  "1959"    420
#  "1960"    472
# Name: 4, dtype: object
# 5 Month      JUN
#  "1958"    435
#  "1959"    472
#  "1960"    535
# Name: 5, dtype: object
# 6 Month      JUL
#  "1958"    491
#  "1959"    548
#  "1960"    622
# Name: 6, dtype: object
# 7 Month      AUG
#  "1958"    505
#  "1959"    559
#  "1960"    606
# Name: 7, dtype: object
# 8 Month      SEP
#  "1958"    404
#  "1959"    463
#  "1960"    508
# Name: 8, dtype: object
# 9 Month      OCT
#  "1958"    359
#  "1959"    407
#  "1960"    461
# Name: 9, dtype: object
# 10 Month      NOV
#  "1958"    310
# ...

# %%
#itertuples()
for row in data.itertuples():
  print(row)
# Out:
# Pandas(Index=0, Month='JAN', _2=340, _3=360, _4=417)
# Pandas(Index=1, Month='FEB', _2=318, _3=342, _4=391)
# Pandas(Index=2, Month='MAR', _2=362, _3=406, _4=419)
# Pandas(Index=3, Month='APR', _2=348, _3=396, _4=461)
# Pandas(Index=4, Month='MAY', _2=363, _3=420, _4=472)
# Pandas(Index=5, Month='JUN', _2=435, _3=472, _4=535)
# Pandas(Index=6, Month='JUL', _2=491, _3=548, _4=622)
# Pandas(Index=7, Month='AUG', _2=505, _3=559, _4=606)
# Pandas(Index=8, Month='SEP', _2=404, _3=463, _4=508)
# Pandas(Index=9, Month='OCT', _2=359, _3=407, _4=461)
# Pandas(Index=10, Month='NOV', _2=310, _3=362, _4=390)
# Pandas(Index=11, Month='DEC', _2=337, _3=405, _4=432)

# %% [markdown]
# ##.date_range function
# 1. First parameter: start= ‘dd/mm/yyyy’.
# 2. Second parameter: periods= n, where n is no of periods or date time elements you need.
# 3. Third parameter: freq= ‘x’, where ‘x’ can be ‘H’(hour), ‘D’(days), ‘W’(weeks), ‘M’(month), ‘Y’(years), etc.

# %%
#create Pandas datetime object
dates=pd.date_range(start='30/03/2024', periods=10, freq='H')
dates
# Out:
# <ipython-input-29-9b489baf3469>:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   dates=pd.date_range(start='30/03/2024', periods=10, freq='H')
# DatetimeIndex(['2024-03-30 00:00:00', '2024-03-30 01:00:00',
#                '2024-03-30 02:00:00', '2024-03-30 03:00:00',
#                '2024-03-30 04:00:00', '2024-03-30 05:00:00',
#                '2024-03-30 06:00:00', '2024-03-30 07:00:00',
#                '2024-03-30 08:00:00', '2024-03-30 09:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
#date in yyyy-mm-dd format
data1=pd.DataFrame()
data1['date']=pd.date_range('30/03/2024', periods = 72, freq ='H')
data1[:5]
# Out:
# <ipython-input-30-cd265eab8dfb>:3: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   data1['date']=pd.date_range('30/03/2024', periods = 72, freq ='H')
#                  date
# 0 2024-03-30 00:00:00
# 1 2024-03-30 01:00:00
# 2 2024-03-30 02:00:00
# 3 2024-03-30 03:00:00
# 4 2024-03-30 04:00:00

# %%
data1['year']=data1['date'].dt.year #creates 'year' column and extracts month
data1['month']=data1['date'].dt.month #creates ‘month’ column and extracts month
data1['day']=data1['date'].dt.day #creates 'day' column and extracts month
data1['hour']=data1['date'].dt.hour #creates 'hour' column and extracts month
data1['minute']=data1['date'].dt.minute #creates 'minute' column and extracts month
data1['seconds']=data1['date'].dt.second  #creates 'second' column and extracts month
data1[24:30]
# Out:
#                   date  year  month  day  hour  minute  seconds
# 24 2024-03-31 00:00:00  2024      3   31     0       0        0
# 25 2024-03-31 01:00:00  2024      3   31     1       0        0
# 26 2024-03-31 02:00:00  2024      3   31     2       0        0
# 27 2024-03-31 03:00:00  2024      3   31     3       0        0
# 28 2024-03-31 04:00:00  2024      3   31     4       0        0
# 29 2024-03-31 05:00:00  2024      3   31     5       0        0

# %%
#present time as a timestamp in Pandas
present_time = pd.Timestamp.now()
present_time
# Out:
# Timestamp('2024-03-30 18:35:32.103288')

# %%
#Pandas TimeDelta
dataflair_time= pd.Timedelta('17 days 7 hours 45 minutes 56 seconds') #with strings
dataflair_time
# Out:
# Timedelta('17 days 07:45:56')

# %%
dataflair_time2= pd.Timedelta(19,unit='h')
dataflair_time2
# Out:
# Timedelta('0 days 19:00:00')

# %%
dataflair_time3= pd.Timedelta(days=9,minutes=45)
dataflair_time3
# Out:
# Timedelta('9 days 00:45:00')

# %%
#Pandas Time Series
dataflair_dict= {'date': ['2018-06-02 12:30:04', '2018-07-02 01:27:03', '2018-07-15 17:23:12', '2018-07-30 05:34:05', '2018-08-04 19:17:23', '2018-08-12 03:12:34', '2018-09-03 09:42:05', '2018-09-03 15:54:08', '2018-09-04 18:47:16', '2018-09-04 17:37:25'], 'Sales': [134, 225, 216, 65, 15, 114, 236, 215, 92, 61]}
dataflair_df = pd.DataFrame(dataflair_dict, columns = ['date', 'sales'])
dataflair_df
# Out:
#                   date sales
# 0  2018-06-02 12:30:04   NaN
# 1  2018-07-02 01:27:03   NaN
# 2  2018-07-15 17:23:12   NaN
# 3  2018-07-30 05:34:05   NaN
# 4  2018-08-04 19:17:23   NaN
# 5  2018-08-12 03:12:34   NaN
# 6  2018-09-03 09:42:05   NaN
# 7  2018-09-03 15:54:08   NaN
# 8  2018-09-04 18:47:16   NaN
# 9  2018-09-04 17:37:25   NaN

# %% [markdown]
# ###Pandas Options and Customizations
# Common default values-
#
#   1. display.max_rows and display.max_columns which shows the default number of rows and columns.
#   2. display.max_colwidth which gives us the maximum width of the column
#   3. display.expand_frame_repr which gives us DataFrames that is spread across numerous pages.
#   4. display.precision gives us the precision of the decimal numbers

# %%
#Pandas.get_option()
dataflair= pd.get_option("display.max_rows")
dataflair2= pd.get_option("display.max_columns")
print(dataflair,dataflair2)
# Out:
# 60 20

# %%
#Pandas.set_option()
pd.set_option("display.max_rows",90)
dataflair3= pd.get_option("display.max_rows")
print(dataflair3)
# Out:
# 90

# %%
pd.set_option("display.max_columns",30)
dataflair4= pd.get_option("display.max_columns")
print(dataflair4)
# Out:
# 30

# %%
#Pandas.reset_option
pd.reset_option("display.max_rows")
dataflair5= pd.get_option("display.max_rows")
print(dataflair5)
# Out:
# 60

# %%
#Pandas.describe_option
pd.describe_option("display.max_rows")
# Out:
# display.max_rows : int
#     If max_rows is exceeded, switch to truncate view. Depending on
#     `large_repr`, objects are either centrally truncated or printed as
#     a summary view. 'None' value means unlimited.
#
#     In case python/IPython is running in a terminal and `large_repr`
#     equals 'truncate' this can be set to 0 and pandas will auto-detect
#     the height of the terminal and print a truncated object which fits
#     the screen height. The IPython notebook, IPython qtconsole, or
#     IDLE do not run in a terminal and hence it is not possible to do
#     correct auto-detection.
#     [default: 60] [currently: 60]

# %%
pd.describe_option("display.max_columns")
# Out:
# display.max_columns : int
#     If max_cols is exceeded, switch to truncate view. Depending on
#     `large_repr`, objects are either centrally truncated or printed as
#     a summary view. 'None' value means unlimited.
#
#     In case python/IPython is running in a terminal and `large_repr`
#     equals 'truncate' this can be set to 0 and pandas will auto-detect
#     the width of the terminal and print a truncated object which fits
#     the screen width. The IPython notebook, IPython qtconsole, or IDLE
#     do not run in a terminal and hence it is not possible to do
#     correct auto-detection.
#     [default: 20] [currently: 30]

# %%
#Pandas.option_context
with pd.option_context("display.max_rows",30):
      print(pd.get_option("display.max_rows"))
# Out:
# 30

# %% [markdown]
# ##Aggregation in Pandas
# Pandas provide us with a variety of aggregate functions. These functions help to perform various activities on the datasets. The functions are:
#
#   1. .count(): This gives a count of the data in a column.
#   2. .sum(): This gives the sum of data in a column.
#   3. .min() and .max(): This helps to find the minimum value and maximum value, ina function, respectively.
#   4. .mean() and .median(): Helps to find the mean and median, of the values in a column, respectively.
